# %% [markdown]
# # Please scroll down below, and see the code under 'Using Facebook Scrapper Library'

# %%
import requests 
from bs4 import BeautifulSoup

# %%
def getdata(url): 
    r = requests.get(url) 
    return r.text

# %%
htmldata = getdata("https://www.facebook.com/groups/613870175328566") 
soup = BeautifulSoup(htmldata, 'html.parser') 
for item in soup.find_all('img'):
    print(item['src'])

# %%
from facebook_scraper import get_posts

# %%
cnt = 0
for post in get_posts(group = 613870175328566, pages=1):
    if(cnt==5) :
        break
    print(post)
    cnt = cnt+1
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15004/1629519320.py in <module>
#       1 cnt = 0
# ----> 2 for post in get_posts(group = 613870175328566, pages=1):
#       3     if(cnt==5) :
#       4         break
#       5     print(post)
#
# ~\CODE_STUFF\Anaconda3\lib\site-packages\facebook_scraper\facebook_scraper.py in _generic_get_posts(self, extract_post_fn, iter_pages_fn, page_limit, options, remove_source, latest_date, max_past_limit, **kwargs)
# ...

# %%
uClient = uReq("https://www.facebook.com/groups/613870175328566")

# %%
from flask import Flask, render_template, request,jsonify
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
uClient

# %%
fbpage = uClient.read()

# %%
fbpage
# Out:
# b'<!DOCTYPE html><html id="facebook" class="_9dls __fb-light-mode" lang="hi" dir="ltr"><head><link data-default-icon="https://static.xx.fbcdn.net/rsrc.php/yD/r/d4ZIVX-5C-b.ico" data-badged-icon="https://static.xx.fbcdn.net/rsrc.php/ye/r/Ta8_J_nYekI.ico" rel="shortcut icon" href="https://static.xx.fbcdn.net/rsrc.php/yD/r/d4ZIVX-5C-b.ico" /><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=2,shrink-to-fit=no" /><link rel="alternate" hreflang="x-default" href="https://www.facebook.com/groups/613870175328566/" /><link rel="alternate" hreflang="ar" href="https://ar-ar.facebook.com/groups/613870175328566/" /><link rel="alternate" hreflang="bg" href="https://bg-bg.facebook.com/groups/613870175328566/" /><link rel="alternate" hreflang="bn" href="https://bn-in.facebook.com/groups/613870175328566/" /><link rel="alternate" hreflang="bs" href="https://bs-ba.facebook.com/groups/613870175328566/" /><link rel="alternate" hreflang="cs" href="https://cs-cz.facebook.com/g
# ...

# %%
uClient.close()

# %%
fbpage_html = bs(fbpage,"html.parser")

# %%
fbpage_html
# Out:
# <!DOCTYPE html>
# ...

# %%
posts = fbpage_html.find_all("div" , {"class" : "x1ja2u2z xh8yej3 x1n2onr6 x1yztbdb"})

# %%
len(posts)
# Out:
# 0

# %%
print(posts)
# Out:
# []

# %% [markdown]
# # Using Facebook Scrapper libarary from github

# %%
from facebook_scraper import get_posts

username_list = []
cnt = 0
for post in get_posts(group = 613870175328566, pages=1):
#     posts_list.append(post)
#     print(post['username'])
    if(cnt==20) : 
        break
    username_list.append(post['username'])
    cnt+=1

# %%
for i in username_list : 
    print(i)
# Out:
# Lesley Ecc ने एक लिंक शेयर किया.
# 25 सितंबर को 3:34 AM पर ·
# Worth a watch. Happy Netflixing!
# #netflixrecommendations
# YOUTUBE.COM
# Tudum: A Netflix Global Fan Event
# #Tudum is Netflix's home for fandom! Watch your favorite stars and creators from around the world on the virtual stage for an exciting day full of Netflix ne...
# 102 पसंद7 कमेंट1 साझाकरण
# लाइक करें
# और प्रतिक्रियाएँ दिखाएँ
# शेयर करें
# इस पोस्ट पर कमेंट करने की सुविधा बंद कर दी गई है.
# सबसे नई एक्टिविटी
# Lorraine Shanahan‎Netflix Recommendations
# 3 घंटे ·
# Looking for series to watch with my 12 yr old daughter
# 47 पसंद156 कमेंट
# लाइक करें
# और प्रतिक्रियाएँ दिखाएँ
# शेयर करें
# इस पोस्ट पर कमेंट करने की सुविधा बंद कर दी गई है.
# Leanne Cohen‎Netflix Recommendations
# 3 घंटे ·
# ...

# %%
from facebook_scraper import get_posts

img_list = []
cnt = 0
for post in get_posts(group = 613870175328566, pages=1):
#     posts_list.append(post)
#     print(post['username'])
    if(cnt==20) : 
        break
    img_list.append(post['image'])
    cnt+=1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15004/2854321922.py in <module>
#       3 img_list = []
#       4 cnt = 0
# ----> 5 for post in get_posts(group = 613870175328566, pages=1):
#       6 #     posts_list.append(post)
#       7 #     print(post['username'])
#
# ~\CODE_STUFF\Anaconda3\lib\site-packages\facebook_scraper\facebook_scraper.py in _generic_get_posts(self, extract_post_fn, iter_pages_fn, page_limit, options, remove_source, latest_date, max_past_limit, **kwargs)
#    1115                 logger.debug("Extracting posts from page %s", i)
#    1116                 for post_element in page:
# -> 1117                     post = extract_post_fn(post_element, options=options, request_fn=self.get)
#    1118                     if remove_source:
#    1119                         post.pop('source', None)
#
# ...

# %%
for i in img_list : 
    print(i)
# Out:
# https://m.facebook.com/photo/view_full_size/?fbid=495334992644706&ref_component=mbasic_photo_permalink&ref_page=%2Fwap%2Fphoto.php&refid=13&_ft_=qid.-5297930117411930637%3Amf_story_key.5846547455394119%3Atop_level_post_id.5846547455394119%3Atl_objid.5846547455394119%3Acontent_owner_id_new.100065046292619%3Apage_id.613870175328566%3Asrc.22%3Aphoto_id.495334992644706%3Astory_location.6%3Astory_attachment_style.photo%3Afilter.GroupStoriesByActivityEntQuery%3Aott.ottAX-yREpM4a_ishFQ%3Asty.308%3Aent_attachement_type.MediaAttachment%3Apage_insights.%7B%22613870175328566%22%3A%7B%22page_id%22%3A613870175328566%2C%22page_id_type%22%3A%22group%22%2C%22actor_id%22%3A100065046292619%2C%22dm%22%3A%7B%22isShare%22%3A0%2C%22originalPostOwnerID%22%3A0%7D%2C%22psn%22%3A%22EntGroupMallPostCreationStory%22%2C%22post_context%22%3A%7B%22object_fbtype%22%3A657%2C%22publish_time%22%3A1667627136%2C%22story_name%22%3A%22EntGroupMallPostCreationStory%22%2C%22story_fbid%22%3A%5B5846547455394119%5D%7D%2C%22rol
# ...
